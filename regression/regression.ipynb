# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %%
df = pd.read_csv('../HouseSale.csv')
df.head()
# Out:
#    square Meter  bedroom  bathroom  House age (years)  zone Rating  \
# 0          50.3        5         2                  8            1
# 1          50.9        2         1                 21            1
# 2          53.4        3         1                 10            1
# 3          56.4        5         3                  8            1
# 4          56.6        1         3                 16            1
#
#    price (USD)
# 0       206042
# 1       179398
# 2       187509
# 3       242866
# 4       158455

# %% [markdown]
# เช้กว่ามีค่า nan ไหม

# %%
df.isnull().sum()
# Out:
# square Meter         0
# bedroom              0
# bathroom             0
# House age (years)    0
# zone Rating          0
# price (USD)          0
# dtype: int64
